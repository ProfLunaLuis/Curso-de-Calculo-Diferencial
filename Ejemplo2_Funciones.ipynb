# %% [markdown]
# <a href="https://colab.research.google.com/github/ProfLunaLuis/Curso-de-Calculo-Diferencial/blob/main/Ejemplo2_Funciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Ejemplo 2 
#Grafica de funciones 
#Calculo diferencial
from sympy.solvers import solve
from sympy import Symbol
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(-4,4,100)
y = x**3-4*x
plt.plot(x, y, '-b', label='y=x**2-2')
#plt.title('Graph of y=2x+1')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='upper left')
plt.grid()
plt.show()
x = Symbol('x')
print(solve(x**2-2, x))
# Out:
# [-sqrt(2), sqrt(2)]
